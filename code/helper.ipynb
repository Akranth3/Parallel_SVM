# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from sklearn.svm import SVC

# %%
df = pd.read_csv('../model/Two_class/model.csv')

# %%
10000*785*8/1000000
# Out:
# 62.8

# %%
# Load the CSV file into a NumPy array
df = pd.read_csv('../Data/IRIS/Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df['Species'] = df['Species'].map({'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2})

# %%
df.to_csv('../Data/IRIS/Iris.csv', index=False)

# %%
train_data = df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
train_labels = df['Species']

# %%
unique_labels = train_labels.unique()
mappping = {k: v for v, k in enumerate(unique_labels)}
train_labels = train_labels.map(mappping)
train_labels = train_labels.values

# %%
df = pd.read_csv('../Data/Two_class/data_100000.csv')

# %%
df.columns
# Out:
# Index(['Id', 'f1', 'f2', 'y1'], dtype='object')

# %%
train_data = df[['f1','f2']]
train_labels = df['y1']

# %%
start_time = time.time()

svm_classifier = SVC(kernel='linear')

# Train the classifier on the training data
svm_classifier.fit(train_data, train_labels)

end_time = time.time()
execution_time = end_time - start_time
print("Execution time:", execution_time)
# Out:
# Execution time: 1.7357072830200195

# %%
accuracy = svm_classifier.score(train_data, train_labels)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.99852

# %%
data = pd.read_csv('../Benchmark.csv')

# %%
new_entry = {'dataset': 'Two_class_100000', 'classifier': 'Python-sklearn-SVM-Linear', 'accuracy': 0.991, 'time': execution_time, 'miscellaneous': None}

# %%
def add_to_bechmark(new_entry):
    data = pd.read_csv('../Benchmark.csv')

    data.loc[len(data.index)] = new_entry

    data.to_csv('../Benchmark.csv', index=False)
    print("Added to benchmark")
    return data

# %%
add_to_bechmark(new_entry)
# Out:
# Added to benchmark
#              dataset                 classifier  accuracy       time  threads
# 0               IRIS  Python-sklearn-SVM-Linear  0.993333   0.002626      NaN
# 1              MNIST  Python-sklearn-SVM-Linear  0.980000   0.003000      NaN
# 2    Two_class_20000  Python-sklearn-SVM-Linear  0.991000   0.604084      NaN
# 3               IRIS                 Serial_SVM  0.985000   0.004183      NaN
# 4               IRIS            Parallel_OPENMP  0.985000   0.085224      1.0
# 5               IRIS            Parallel_OPENMP  0.985000   0.118397      2.0
# 6               IRIS            Parallel_OPENMP  0.985000   0.176603      4.0
# 7               IRIS            Parallel_OPENMP  0.985000   0.479955      8.0
# 8               IRIS            Parallel_OPENMP  0.985000   0.267888     10.0
# 9               IRIS            Parallel_OPENMP  0.985000   0.302867     12.0
# 10              IRIS            Parallel_OPENMP  0.985000   0.381321     16.0
# 11              IRIS            Parallel_OPENMP  0.985000   0.450980     20.0
# 12              IRIS           Parallel_OPENACC  0.985000   0.191817      NaN
# 13   Two_class_20000            Parallel_OPENMP  0.985000   7.505408      1.0
# 14   Two_class_20000            Parallel_OPENMP  0.985000   4.554542      2.0
# 15   Two_class_20000            Parallel_OPENMP  0.985000   2.683628      4.0
# 16   Two_class_20000            Parallel_OPENMP  0.985000   1.893673      8.0
# 17   Two_class_20000            Parallel_OPENMP  0.985000   1.870137     16.0
# 18   Two_class_20000           Parallel_OPENACC  0.985000   6.736135     10.0
# 19   Two_class_20000           Parallel_OPENACC  0.985000   7.568177     20.0
# 20   Two_class_20000           Parallel_OPENACC  0.985000   7.546082     30.0
# 21   Two_class_20000           Parallel_OPENACC  0.985000   6.960664     50.0
# 22  Two_class_100000           Parallel_OPENACC  0.985000  55.106237     10.0
# 23  Two_class_100000           Parallel_OPENACC  0.985000  51.355912     20.0
# 24  Two_class_100000           Parallel_OPENACC  0.985000  49.263075     30.0
# 25  Two_class_100000           Parallel_OPENACC  0.985000  48.213410     50.0
# 26  Two_class_100000           Parallel_OPENACC  0.985000  46.798283    200.0
# 27  Two_class_100000           Parallel_OPENACC  0.985000  47.231734    200.0
# 28  Two_class_100000            Parallel_OPENMP  0.985000  23.041969      2.0
# 29  Two_class_100000            Parallel_OPENMP  0.985000  13.642377      4.0
# 30  Two_class_100000            Parallel_OPENMP  0.985000  10.513116      8.0
# 31  Two_class_100000            Parallel_OPENMP  0.985000  10.738025     12.0
# 32  Two_class_100000            Parallel_OPENMP  0.985000   9.166583     16.0
# 33  Two_class_100000            Parallel_OPENMP  0.985000   9.087416     32.0
# 34  Two_class_100000  Python-sklearn-SVM-Linear  0.991000   1.735707      NaN
